# %%
#----------------------IMPORT DEPENDENCIES---------------------------
#-------------------
import numpy as np  #LIBRARY TO WORK WITH ARRAYS
import pandas as pd   #LIBRARY TO MAKE DATAFRAMES, DATAFRAMES ARE STRUCTURED TABLES
import matplotlib.pyplot as plt # FOR PLOTTING AS WE NEED TO MAKE SOME DATA ANALYSIS
 
import seaborn as sns #Seaborn is an open-source Python library built on top of matplotlib. 
                        #It is used for data visualization and exploratory data analysis. 
                        #Seaborn works easily with dataframes and the Pandas library. 
                        #The graphs created can also be customized easily
from sklearn.model_selection import train_test_split
 
from sklearn import metrics #The sklearn.metrics module implements functions assessing prediction error for specific purposes

# %%
#----------------------------------DATA COLLECTION & PROCESSING-----------------------------

# %%
#loading data from csv file into pandas dataframe 
calories= pd.read_csv("calories.csv")

# %%
#print first 5 rows of the dataframe : use head function
calories.head()
# Out:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0

# %%
exercise_data = pd.read_csv("exercise.csv")

# %%
exercise_data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8

# %%
#Combining 2 dataframes
calories_data = pd.concat([exercise_data, calories['Calories']], axis=1) 
#here we need only calories column from calories dataframe,
#axis =1 : represents joining column wise

# %%
calories_data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
#checking no of rows and columns 
calories_data.shape
# Out:
# (15000, 9)

# %%
calories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
#checking for missing values in each column
calories_data.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
#----------------------------------------DATA ANALYSIS--------------------------------

# %%
#Get some STATISTICAL MEASURES about data
calories_data.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# 25%       88.000000     39.600000     35.000000
# 50%       96.000000     40.200000     79.000000
# 75%      103.000000     40.600000    138.000000
# max      128.000000     41.500000    314.000000

# %%
# DATA VISUALISATION

# %%
# to set a basic theme 
sns.set()

# %%
#plotting the gender, which is a ctegorical column , means it has only 2 values
sns.countplot(calories_data['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
#plotting age, age has distinct values , not categorical
sns.distplot(calories_data['Age'])
# Out:
# C:\Users\BHARTI\AppData\Local\Temp\ipykernel_37444\2401185928.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calories_data['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#plotting height, age has distinct values , not categorical
sns.distplot(calories_data['Height'])
# Out:
# C:\Users\BHARTI\AppData\Local\Temp\ipykernel_37444\1558727971.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calories_data['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
#plotting weight, age has distinct values , not categorical
sns.distplot(calories_data['Weight'])
# Out:
# C:\Users\BHARTI\AppData\Local\Temp\ipykernel_37444\1418373622.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calories_data['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
#plotting duration, age has distinct values , not categorical
sns.distplot(calories_data['Duration'])
# Out:
# C:\Users\BHARTI\AppData\Local\Temp\ipykernel_37444\1298996855.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(calories_data['Duration'])
# <Axes: xlabel='Duration', ylabel='Density'>

# %%
#--------------FINDING CORRELATION B/W DATASET

# %%
import pandas as pd 
calories_data = pd.read_csv(r'C:\Users\BHARTI\Downloads\Calories-Burnt-Prediction_ML_Python-main\Calories-Burnt-Prediction_ML_Python-main\calories.csv')

calories_data = calories_data.select_dtypes(include=[np.number])
correlation = calories_data.corr()

print(correlation)
calories_data = calories_data.dropna()  # Drop rows with missing values
# Out:
#            User_ID  Calories
# User_ID   1.000000 -0.001661
# Calories -0.001661  1.000000

# %%
#constructing  a heat map to understand the correlation
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(correlation,cbar=True, square= True, fmt = '.')
# Out:
# <Axes: >

# %%
#Here we can see that the correlation value between Caories and Heart Rate, Caories and Body Temp are high and b/w 0.8 to 1. 
#Means highly correlated

# %%
#------Converting Text data to numerical values

# %%
calories_data.replace({'Gender': {'male' : 0, 'female' : 1}}, inplace=True)

# %%
calories_data.head()
# Out:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0

# %%
#----------------------------SEPARATING FEATURES AND TARGET-----------------------------

# %%
X = calories_data.drop(columns = ['User_ID', 'Calories'], axis =1)
Y= calories_data['Calories']   # conatins only calories column

# %%
print(X)
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0           0   68   190.0    94.0      29.0       105.0       40.8
# 1           1   20   166.0    60.0      14.0        94.0       40.3
# 2           0   69   179.0    79.0       5.0        88.0       38.7
# 3           1   34   179.0    71.0      13.0       100.0       40.5
# 4           1   27   154.0    58.0      10.0        81.0       39.8
# ...       ...  ...     ...     ...       ...         ...        ...
# 14995       1   20   193.0    86.0      11.0        92.0       40.4
# 14996       1   27   165.0    65.0       6.0        85.0       39.2
# 14997       1   43   159.0    58.0      16.0        90.0       40.1
# 14998       0   78   193.0    97.0       2.0        84.0       38.3
# 14999       0   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 7 columns]

# %%
print(Y)
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %%
#-------------SPLITTING DATA INTO TRAINING DATA AND TEST DATA

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (15000, 0) (12000, 0) (3000, 0)

# %%
#--------------MODEL TRAINING

# %%
#XGBoost Regressor

# %%
#load the model
from xgboost import XGBRegressor
model = XGBRegressor()

# %%
print("X shape:", X.shape)

print("y shape:", y.shape)
# Out:
# X shape: (5, 2)
# y shape: (5,)

# %%
#EVALUATE MODEL

# %%
#Prediction on Test Data
test_data_prediction= model.predict(X_test)

# %%
print(test_data_prediction)
# Out:
# [127.823784 226.00154   38.66253  ... 144.3636    22.767195  89.87375 ]

# %%
#------------MEAN ABSOLUTE ERROR


print("y_test shape:", y_test.shape)
print("test_data_prediction shape:", test_data_prediction.shape)
# Out:
# y_test shape: (1,)
# test_data_prediction shape: (1,)

# %%
mae = metrics.mean_absolute_error(y_test, test_data_prediction)

print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 0.9998934268951416
